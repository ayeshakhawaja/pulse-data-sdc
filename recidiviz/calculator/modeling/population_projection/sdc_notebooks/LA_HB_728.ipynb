# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#To-Do" data-toc-modified-id="To-Do-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>To Do</a></span></li><li><span><a href="#Turning-admissions-into-outflows_data" data-toc-modified-id="Turning-admissions-into-outflows_data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Turning admissions into outflows_data</a></span></li><li><span><a href="#Turning-sentence_length-into-transitions_data" data-toc-modified-id="Turning-sentence_length-into-transitions_data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Turning sentence_length into transitions_data</a></span></li><li><span><a href="#Turn-population-into-total_population_data" data-toc-modified-id="Turn-population-into-total_population_data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Turn population into total_population_data</a></span></li><li><span><a href="#Debugging" data-toc-modified-id="Debugging-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Debugging</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Modeling</a></span></li></ul></div>

# %%
import os
import sys
sys.path.insert(0, os.path.relpath('../../../../..')) 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from recidiviz.calculator.modeling.population_projection.super_simulation.super_simulation_factory import SuperSimulationFactory
from recidiviz.calculator.modeling.population_projection.transition_table import TransitionTable
from recidiviz.calculator.modeling.population_projection.shell_compartment import ShellCompartment
from recidiviz.calculator.modeling.population_projection.spark_policy import SparkPolicy
from recidiviz.calculator.modeling.population_projection.utils.spark_bq_utils import upload_spark_model_inputs
import pandas as pd
from functools import partial

pd.set_option('display.max_rows', 500)
pd.set_option('max_columns', 100)

# %%
admissions = pd.read_csv(
    '../state/LA/LA_data/LA Data - Admissions by crime type.csv',
    index_col=0
)
age_at_admission = pd.read_csv(
    '../state/LA/LA_data/LA Data - Age at admission by crime type x race.csv',
    index_col=0
)
age_today = pd.read_csv(
    '../state/LA/LA_data/LA Data - Age today by crime type x race.csv',
    index_col=0
)
population = pd.read_csv(
    '../state/LA/LA_data/LA Data - Population by crime type.csv',
    index_col=0
)
recidivism = pd.read_csv(
    '../state/LA/LA_data/LA Data - Recidivism.csv',
    index_col=0
)
releases = pd.read_csv(
    '../state/LA/LA_data/LA Data - Releases by crime type.csv',
    index_col=0
)

sentence_length = pd.read_csv(
    '../state/LA/LA_data/LA Data - Sentence Length by crime type x race.csv',
    index_col=0
)

# %% [markdown]
# # To Do
# - Transitions data
#     - check on rounding question
#     - what to do about 50+ / Life / Death
#     - include recidivism
#
# - Total population data
#     - does time_step have to be an integer?
#     - include DOC projections? I think no

# %% [markdown]
# # Turning admissions into outflows_data

# %%
admissions
# Out:
#                                                     violent  property    drug  \
# https://doc.louisiana.gov/about-the-dpsc/annual...
# 1994                                                 1793.0    4087.0  4493.0
# 1995                                                 1843.0    4043.0  4837.0
# 1996                                                 1888.0    4423.0  5009.0
# 1997                                                 2252.0    4837.0  5547.0
# 1998                                                 2496.0    4955.0  5970.0
# 1999                                                 3064.0    5342.0  5348.0
# 2000                                                 3499.0    5428.0  5521.0
# 2001                                                 3171.0    5339.0  5465.0
# 2002                                                 2969.0    5278.0  5737.0
# 2003                                                 2859.0    5185.0  6279.0
# 2004                                                 2749.0    5396.0  6120.0
# 2005                                                 2385.0    5176.0  5855.0
# 2006                                                 2518.0    5263.0  5968.0
# 2007                                                 2799.0    5469.0  6380.0
# 2008                                                 2735.0    5600.0  6296.0
# 2009                                                 3080.0    5761.0  6444.0
# 2010                                                 3241.0    5939.0  6081.0
# 2016                                                   16278.0
# 2017                                                   16443.0
# 2018                                                   15994.0
# 2019                                                   16248.0
# 2020                                                    9690.0
# 2021                                                       NaN
# 2022                                                       NaN

# %%
admissions_jr = admissions.copy()

#adding the sex nonviolent category to Other because it only existed as it's own category since 2016
admissions_jr['Sex nonviolent'] = admissions_jr['Sex nonviolent'].fillna(0)
admissions_jr['others'] += admissions_jr['Sex nonviolent']
admissions_jr = admissions_jr.drop(['Sex nonviolent', 'Unnamed: 7', 'Unnamed: 8', 'total'], axis = 1)

#2021 and 2022 were both NA for all crime types
admissions_jr = admissions_jr.drop([2021, 2022]) 

# time_step
admissions_jr.index.names = ['year']
admissions_jr = admissions_jr.reset_index()
admissions_jr['time_step'] = (admissions_jr.year - 2020)

admissions_jr
# Out:
#     year  violent  property    drug  others  time_step
# 0   1994   1793.0    4087.0  4493.0  1691.0        -26
# 1   1995   1843.0    4043.0  4837.0  1905.0        -25
# 2   1996   1888.0    4423.0  5009.0  2210.0        -24
# 3   1997   2252.0    4837.0  5547.0  2420.0        -23
# 4   1998   2496.0    4955.0  5970.0  2207.0        -22
# 5   1999   3064.0    5342.0  5348.0  1607.0        -21
# 6   2000   3499.0    5428.0  5521.0  1590.0        -20
# 7   2001   3171.0    5339.0  5465.0  1598.0        -19
# 8   2002   2969.0    5278.0  5737.0  1575.0        -18
# 9   2003   2859.0    5185.0  6279.0  1810.0        -17
# 10  2004   2749.0    5396.0  6120.0  1760.0        -16
# 11  2005   2385.0    5176.0  5855.0  1590.0        -15
# 12  2006   2518.0    5263.0  5968.0  1652.0        -14
# 13  2007   2799.0    5469.0  6380.0  1661.0        -13
# 14  2008   2735.0    5600.0  6296.0  1664.0        -12
# 15  2009   3080.0    5761.0  6444.0  1952.0        -11
# 16  2010   3241.0    5939.0  6081.0  1926.0        -10
# 17  2011   3338.0    6305.0  5941.0  1924.0         -9
# 18  2012   3490.0    6359.0  5834.0  1879.0         -8
# 19  2013   3468.0    6329.0  5436.0  1812.0         -7
# 20  2014   3362.0    5802.0  5330.0  2049.0         -6
# 21  2015   3447.0    5829.0  5072.0  2084.0         -5
# 22  2016   3514.0    5802.0  4981.0  2114.0         -4
# 23  2017   3664.0    5794.0  4905.0  2080.0         -3
# 24  2018   3926.0    5322.0  4696.0  2050.0         -2
# 25  2019   3847.0    5202.0  5018.0  2181.0         -1
# 26  2020   2305.0    3015.0  2877.0  1493.0          0

# %%
2305 + 3015 + 2877 + 1493
# Out:
# 9690

# %%
#crime_type
admissions_jr_the_second = pd.DataFrame()
crime_types = ['violent', 'property', 'drug', 'others']
for i, row in admissions_jr.iterrows():
    for j in crime_types:
        new_rows = pd.DataFrame({
            'time_step': [row['time_step'] * 12 + i for i in range(12)],
            'crime_type': [j] * 12,
            'total_population': [row[j] / 12] * 12,
            'compartment': ['pretrial'] * 12,
            'outflow_to': ['prison'] * 12
        })
        admissions_jr_the_second = admissions_jr_the_second.append(new_rows, ignore_index=True)

# %%
#collapse crime types for hb728
admissions_jr_the_second = admissions_jr_the_second.groupby('time_step', as_index=False).sum()
admissions_jr_the_second['compartment'] = 'pretrial'
admissions_jr_the_second['outflow_to'] = 'prison'
admissions_jr_the_second['crime_type'] = 'NA'

admissions_jr_the_second.head()
# Out:
#    time_step  total_population compartment outflow_to crime_type
# 0     -312.0       1005.333333    pretrial     prison         NA
# 1     -311.0       1005.333333    pretrial     prison         NA
# 2     -310.0       1005.333333    pretrial     prison         NA
# 3     -309.0       1005.333333    pretrial     prison         NA
# 4     -308.0       1005.333333    pretrial     prison         NA

# %%
outflows_data = admissions_jr_the_second
outflows_data.total_population = outflows_data.total_population.astype(float)
outflows_data.time_step = outflows_data.time_step.astype(int)
outflows_data
# Out:
#      time_step  total_population compartment outflow_to crime_type
# 0         -312       1005.333333    pretrial     prison         NA
# 1         -311       1005.333333    pretrial     prison         NA
# 2         -310       1005.333333    pretrial     prison         NA
# 3         -309       1005.333333    pretrial     prison         NA
# 4         -308       1005.333333    pretrial     prison         NA
# 5         -307       1005.333333    pretrial     prison         NA
# 6         -306       1005.333333    pretrial     prison         NA
# 7         -305       1005.333333    pretrial     prison         NA
# 8         -304       1005.333333    pretrial     prison         NA
# 9         -303       1005.333333    pretrial     prison         NA
# 10        -302       1005.333333    pretrial     prison         NA
# 11        -301       1005.333333    pretrial     prison         NA
# 12        -300       1052.333333    pretrial     prison         NA
# 13        -299       1052.333333    pretrial     prison         NA
# 14        -298       1052.333333    pretrial     prison         NA
# 15        -297       1052.333333    pretrial     prison         NA
# 16        -296       1052.333333    pretrial     prison         NA
# 17        -295       1052.333333    pretrial     prison         NA
# 18        -294       1052.333333    pretrial     prison         NA
# 19        -293       1052.333333    pretrial     prison         NA
# 20        -292       1052.333333    pretrial     prison         NA
# 21        -291       1052.333333    pretrial     prison         NA
# 22        -290       1052.333333    pretrial     prison         NA
# 23        -289       1052.333333    pretrial     prison         NA
# 24        -288       1127.500000    pretrial     prison         NA
# 25        -287       1127.500000    pretrial     prison         NA
# 26        -286       1127.500000    pretrial     prison         NA
# 27        -285       1127.500000    pretrial     prison         NA
# 28        -284       1127.500000    pretrial     prison         NA
# 29        -283       1127.500000    pretrial     prison         NA
# 30        -282       1127.500000    pretrial     prison         NA
# 31        -281       1127.500000    pretrial     prison         NA
# 32        -280       1127.500000    pretrial     prison         NA
# 33        -279       1127.500000    pretrial     prison         NA
# 34        -278       1127.500000    pretrial     prison         NA
# 35        -277       1127.500000    pretrial     prison         NA
# 36        -276       1254.666667    pretrial     prison         NA
# 37        -275       1254.666667    pretrial     prison         NA
# 38        -274       1254.666667    pretrial     prison         NA
# 39        -273       1254.666667    pretrial     prison         NA
# 40        -272       1254.666667    pretrial     prison         NA
# 41        -271       1254.666667    pretrial     prison         NA
# 42        -270       1254.666667    pretrial     prison         NA
# 43        -269       1254.666667    pretrial     prison         NA
# 44        -268       1254.666667    pretrial     prison         NA
# 45        -267       1254.666667    pretrial     prison         NA
# 46        -266       1254.666667    pretrial     prison         NA
# 47        -265       1254.666667    pretrial     prison         NA
# 239        -73       1420.416667    pretrial     prison         NA
# 240        -72       1378.583333    pretrial     prison         NA
# 241        -71       1378.583333    pretrial     prison         NA
# 242        -70       1378.583333    pretrial     prison         NA
# 243        -69       1378.583333    pretrial     prison         NA
# 244        -68       1378.583333    pretrial     prison         NA
# 245        -67       1378.583333    pretrial     prison         NA
# 246        -66       1378.583333    pretrial     prison         NA
# 247        -65       1378.583333    pretrial     prison         NA
# 248        -64       1378.583333    pretrial     prison         NA
# 249        -63       1378.583333    pretrial     prison         NA
# 250        -62       1378.583333    pretrial     prison         NA
# 251        -61       1378.583333    pretrial     prison         NA
# 252        -60       1369.333333    pretrial     prison         NA
# 253        -59       1369.333333    pretrial     prison         NA
# 254        -58       1369.333333    pretrial     prison         NA
# 255        -57       1369.333333    pretrial     prison         NA
# 256        -56       1369.333333    pretrial     prison         NA
# 257        -55       1369.333333    pretrial     prison         NA
# 258        -54       1369.333333    pretrial     prison         NA
# 259        -53       1369.333333    pretrial     prison         NA
# 260        -52       1369.333333    pretrial     prison         NA
# 261        -51       1369.333333    pretrial     prison         NA
# 262        -50       1369.333333    pretrial     prison         NA
# 263        -49       1369.333333    pretrial     prison         NA
# 264        -48       1367.583333    pretrial     prison         NA
# 265        -47       1367.583333    pretrial     prison         NA
# 266        -46       1367.583333    pretrial     prison         NA
# 267        -45       1367.583333    pretrial     prison         NA
# 268        -44       1367.583333    pretrial     prison         NA
# 269        -43       1367.583333    pretrial     prison         NA
# 270        -42       1367.583333    pretrial     prison         NA
# 271        -41       1367.583333    pretrial     prison         NA
# 272        -40       1367.583333    pretrial     prison         NA
# 273        -39       1367.583333    pretrial     prison         NA
# 274        -38       1367.583333    pretrial     prison         NA
# 275        -37       1367.583333    pretrial     prison         NA
# 276        -36       1370.250000    pretrial     prison         NA
# 277        -35       1370.250000    pretrial     prison         NA
# 278        -34       1370.250000    pretrial     prison         NA
# 279        -33       1370.250000    pretrial     prison         NA
# 280        -32       1370.250000    pretrial     prison         NA
# 281        -31       1370.250000    pretrial     prison         NA
# 282        -30       1370.250000    pretrial     prison         NA
# 283        -29       1370.250000    pretrial     prison         NA
# 284        -28       1370.250000    pretrial     prison         NA
# 285        -27       1370.250000    pretrial     prison         NA
# 286        -26       1370.250000    pretrial     prison         NA
# 287        -25       1370.250000    pretrial     prison         NA
# 288        -24       1332.833333    pretrial     prison         NA
# 289        -23       1332.833333    pretrial     prison         NA
# 290        -22       1332.833333    pretrial     prison         NA
# 291        -21       1332.833333    pretrial     prison         NA
# 292        -20       1332.833333    pretrial     prison         NA
# 293        -19       1332.833333    pretrial     prison         NA
# 294        -18       1332.833333    pretrial     prison         NA
# 295        -17       1332.833333    pretrial     prison         NA
# 296        -16       1332.833333    pretrial     prison         NA
# 297        -15       1332.833333    pretrial     prison         NA
# 298        -14       1332.833333    pretrial     prison         NA
# 299        -13       1332.833333    pretrial     prison         NA
# 300        -12       1354.000000    pretrial     prison         NA
# 301        -11       1354.000000    pretrial     prison         NA
# 302        -10       1354.000000    pretrial     prison         NA
# 303         -9       1354.000000    pretrial     prison         NA
# 304         -8       1354.000000    pretrial     prison         NA
# 305         -7       1354.000000    pretrial     prison         NA
# 306         -6       1354.000000    pretrial     prison         NA
# 307         -5       1354.000000    pretrial     prison         NA
# 308         -4       1354.000000    pretrial     prison         NA
# 309         -3       1354.000000    pretrial     prison         NA
# 310         -2       1354.000000    pretrial     prison         NA
# 311         -1       1354.000000    pretrial     prison         NA
# 312          0        807.500000    pretrial     prison         NA
# 313          1        807.500000    pretrial     prison         NA
# 314          2        807.500000    pretrial     prison         NA
# 315          3        807.500000    pretrial     prison         NA
# 316          4        807.500000    pretrial     prison         NA
# 317          5        807.500000    pretrial     prison         NA
# 318          6        807.500000    pretrial     prison         NA
# 319          7        807.500000    pretrial     prison         NA
# 320          8        807.500000    pretrial     prison         NA
# 321          9        807.500000    pretrial     prison         NA
# 322         10        807.500000    pretrial     prison         NA
# 323         11        807.500000    pretrial     prison         NA

# %%
outflows_data.groupby('time_step').sum().plot(ylim=[0,None])
# Out:
# <AxesSubplot:xlabel='time_step'>

# %% [markdown]
# # Turning sentence_length into transitions_data

# %%
sentence_length
# Out:
#          Black Black.1   Black.2 Black.3    White White.1   White.2 White.3
# NaN    Violent    Drug  Property   Other  Violent    Drug  Property   Other
# 0-2        193     157       143     168      113     316       183     172
# 3-4        291     178       236     215      127     202       280     181
# 5-6        634     270       320     425      274     242       316     384
# 7-10      1479     570       387     585      524     284       401     583
# 11-16     1322     424       230     353      340     115       149     319
# 17-20     1094     225        64     180      375      53        43     204
# 21-30     1443     146        49     125      544      30        27     185
# 31-50     1424      70        12      48      483      11        14      75
# 50+        741      25         2      23      181       4         3      31
# death       43       0         0       0       19       0         0       0
# life      3135      48        27      23     1143       6        12       8

# %%
sentence_length.index
# Out:
# Index([    nan,   '0-2',   '3-4',   '5-6',  '7-10', '11-16', '17-20', '21-30',
#        '31-50',   '50+', 'death',  'life'],
#       dtype='object')

# %%
long_finite_sentences = sentence_length.loc['50+'].astype(float).sum() / (
    sentence_length.loc[['50+', 'death', 'life']].astype(float).sum().sum()
)
long_finite_sentences
# Out:
# 0.1845085860431129

# %%
transitions_data = sentence_length.copy()
transitions_data = transitions_data.iloc[1:]

for i in range(len(crime_types)):
    num = '' if i == 0 else '.' + str(i)
    transitions_data[crime_types[i]] = transitions_data['Black' + num].astype(float) + transitions_data['White' + num].astype(float)
    
transitions_data = transitions_data[crime_types]

transitions_data.loc['50-50'] = transitions_data.loc['50+'] + transitions_data.loc['death'] + transitions_data.loc['life']
transitions_data = transitions_data.drop(['death', 'life', '50+'])

transitions_data
# Out:
#        violent  property   drug  others
# 0-2      306.0     473.0  326.0   340.0
# 3-4      418.0     380.0  516.0   396.0
# 5-6      908.0     512.0  636.0   809.0
# 7-10    2003.0     854.0  788.0  1168.0
# 11-16   1662.0     539.0  379.0   672.0
# 17-20   1469.0     278.0  107.0   384.0
# 21-30   1987.0     176.0   76.0   310.0
# 31-50   1907.0      81.0   26.0   123.0
# 50-50   5262.0      83.0   44.0    85.0

# %%
transitions_data = transitions_data.reset_index()

# %%
transitions_data = transitions_data.rename(columns={'index': 'compartment_duration'})

# %%
def punk_jr(compartment_duration):
    compartment_duration = compartment_duration.split('-')
    start = float(compartment_duration[0])
    final_duration = start
    
    if len(compartment_duration) > 1:
        end = float(compartment_duration[1])
        final_duration = -start + end + 1
        
    return final_duration * 12

transitions_data_jr = transitions_data.copy()
transitions_data_jr["months_in_group"] = transitions_data_jr['compartment_duration'].apply(punk_jr)


# disallow sentences less than 6 months
transitions_data_jr.loc[0, 'compartment_duration'] = '0.5-2'
transitions_data_jr.loc[0, 'months_in_group'] = 30.0

transitions_data_jr
# Out:
#   compartment_duration  violent  property   drug  others  months_in_group
# 0                0.5-2    306.0     473.0  326.0   340.0             30.0
# 1                  3-4    418.0     380.0  516.0   396.0             24.0
# 2                  5-6    908.0     512.0  636.0   809.0             24.0
# 3                 7-10   2003.0     854.0  788.0  1168.0             48.0
# 4                11-16   1662.0     539.0  379.0   672.0             72.0
# 5                17-20   1469.0     278.0  107.0   384.0             48.0
# 6                21-30   1987.0     176.0   76.0   310.0            120.0
# 7                31-50   1907.0      81.0   26.0   123.0            240.0
# 8                50-50   5262.0      83.0   44.0    85.0             12.0

# %%
transitions_data_jr.property.sum() + transitions_data_jr.violent.sum() + transitions_data_jr.drug.sum() + transitions_data_jr.others.sum()
# Out:
# 26483.0

# %%
transitions_jr_the_second = pd.DataFrame()
crime_types = ['violent', 'property', 'drug', 'others']
prev_months = 6

for i, row in transitions_data_jr.iterrows():
    for j in crime_types:
        for month in range(int(prev_months), int(prev_months + row['months_in_group'])):
            new_row = {'compartment_duration': month, 'crime_type': j, 'total_population': row[j]/(month * row['months_in_group']),
                   'compartment': 'prison', 'outflow_to': 'release'}
            transitions_jr_the_second = transitions_jr_the_second.append(new_row, ignore_index=True)
    prev_months += row['months_in_group']

# collapse crime types for HB 728
transitions_jr_the_second = transitions_jr_the_second.groupby('compartment_duration', as_index=False).sum()
transitions_jr_the_second['compartment'] = 'prison' 
transitions_jr_the_second['outflow_to'] = 'release' 
transitions_jr_the_second['crime_type'] = 'NA'

# %%
#scale down compartment_duration to convert from sentence length to LOS.
avg_LOS = (
    transitions_jr_the_second.compartment_duration * transitions_jr_the_second.total_population
).sum()/transitions_jr_the_second.total_population.sum()

#actual LOS taken from https://www.pewtrusts.org/-/media/legacy/uploadedfiles/pcs_assets/2012/prisontimeservedlouisianapdf.pdf
LOS_scale_factor = 2.5 * 12 / avg_LOS
transitions_jr_the_second.compartment_duration *= LOS_scale_factor

#life sentences should not get shortened
transitions_jr_the_second.loc[
    transitions_jr_the_second.compartment_duration >= 50 * 12 * LOS_scale_factor, 'compartment_duration'
] = 50.0 * 12

#sentences shouldn't get shorter than six months
transitions_jr_the_second.loc[
    transitions_jr_the_second.compartment_duration < 6, 'compartment_duration'
] = 6.0

LOS_scale_factor
# Out:
# 0.29875089539929883

# %%
transitions_jr_the_second = transitions_jr_the_second.append({'compartment_duration': 1, 'crime_type': 'NA', 'total_population': 1, 'compartment': 'release', 'outflow_to': 'release'}, ignore_index = True)

transitions_jr_the_second.compartment_duration = transitions_jr_the_second.compartment_duration.astype(float)
transitions_jr_the_second.total_population = transitions_jr_the_second.total_population.astype(float)




transitions_jr_the_second
# Out:
#      compartment_duration  total_population compartment outflow_to crime_type
# 0                     6.0          8.027778      prison    release         NA
# 1                     6.0          6.880952      prison    release         NA
# 2                     6.0          6.020833      prison    release         NA
# 3                     6.0          5.351852      prison    release         NA
# 4                     6.0          4.816667      prison    release         NA
# ..                    ...               ...         ...        ...        ...
# 614                 600.0          0.735753      prison    release         NA
# 615                 600.0          0.734568      prison    release         NA
# 616                 600.0          0.733387      prison    release         NA
# 617                 600.0          0.732210      prison    release         NA
# 618                   1.0          1.000000     release    release         NA
#
# [619 rows x 5 columns]

# %%
transitions_jr_the_second.groupby('compartment_duration').sum()['total_population'].plot(x='compartment_duration', y='total_population', ylim=[0, None])
# Out:
# <AxesSubplot:xlabel='compartment_duration'>

# %% [markdown]
# # Turn population into total_population_data

# %%
total_population = population.copy()
total_population = total_population.reset_index()
total_population = total_population[:198]
# total_population['year'] = (admissions_jr['https://doc.louisiana.gov/about-the-dpsc/annual-statistics/'] - 2019)
# total_population = total_population.drop(
  #   ['https://doc.louisiana.gov/about-the-dpsc/annual-statistics/', 'State Facilities', 'Local Facilities'],
  #   axis = 1)


TIMESTEP_START = 2020;
MOTHS = { 'Jan':0, 'Feb':1, 'Mar':2, 'Apr':3, 'May':4, 'Jun': 5, 'Jul':6, 'Aug':7, 'Sep':8, 'Oct': 9, 'Nov':10, 'Dec':11 }

total_population = total_population.rename(columns={'https://doc.louisiana.gov/about-the-dpsc/annual-statistics/':'Year', 'Unnamed: 1':'Month', 'State Facilities':'total_population'})

total_population.Year = total_population.Year.astype(int)
total_population.total_population = total_population.total_population.apply(lambda x: x.replace(',', '')).astype(float)


# def timeStep(row):
#     year  = row['Year']
#     month = row['Month']
    
#     timestep = 12 * (year - TIMESTEP_START) + MOTHS[month]
    
#     return timestep


# create a new timestep column
# total_population['timestep'] = total_population.apply(timeStep, axis=1)

total_population['time_step'] = (total_population['Year'] - TIMESTEP_START) * 12 + total_population['Month'].map(MOTHS)
total_population['compartment'] = 'prison'
total_population
# Out:
#      Year Month  total_population Local Facilities   Total  time_step  \
# 0    2005   Jan           19300.0            17066   36366       -180
# 1    2005   Feb           19439.0            17378   36817       -179
# 2    2005   Mar           19569.0            17327   36896       -178
# 3    2005   Apr           19435.0            17431   36866       -177
# 4    2005   May           19484.0            17708   37192       -176
# 5    2005   Jun           19591.0            17645   37236       -175
# 6    2005   Jul           19589.0            17685   37274       -174
# 7    2005   Aug           25378.0            16819   42197       -173
# 8    2005   Sep           25437.0            17953   43390       -172
# 9    2005   Oct           23045.0            17558   40603       -171
# 10   2005   Nov           22065.0            17581   39646       -170
# 11   2005   Dec           21583.0            17456   39039       -169
# 12   2006   Jan           20501.0            17780   38281       -168
# 13   2006   Feb           20255.0            17609   37864       -167
218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   params["data_df"]["simulation_tag"] = simulation_tag
# ../../../../../recidiviz/calculator/modeling/population_projection/utils/spark_bq_utils.py:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   params["data_df"]["date_created"] = upload_time
# ../../../../../recidiviz/calculator/modeling/population_projection/utils/spark_bq_utils.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   params["data_df"][disaggregation_axis] = None

# %% [markdown]
# # Modeling

# %%
# Don't worry about any warnings, as long as this doesn't fail you're in business
spark_sim = SuperSimulationFactory.build_super_simulation(
    '../state/LA/policy_configurations/HB_728_model_inputs.yaml'
)
# Out:
# /Users/pacopoler/.local/share/virtualenvs/recidiviz-data-Jd9N3JcA/lib/python3.8/site-packages/google/cloud/bigquery/table.py:1852: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(
# outflows_data returned 324 results
# transitions_data returned 619 results
# total_population_data returned 198 results

# %%
spark_sim.simulate_baseline(['prison'])
# Out:
# initialization time:  7.2580320835113525
# simulation_time:  5.3260698318481445

# %%
spark_sim.get_arima_output_plots('baseline_projections')
# Out:
# [<AxesSubplot:title={'center':'compartment: pretrial\noutflow_to: prison'}, xlabel='time_step'>]

# %%
# grant rate from here: https://s32082.pcdn.co/wp-content/uploads/2020/02/FY-2019-Annual-Report-Final.pdf
PAROLE_GRANT_RATE = 0.54

age_breakdown = pd.DataFrame({
    'age': ['16', '17', '18', '19-20', '21-24', '25+'],
    '51+ count': [3,7,18,72,222, 688]
})

policy_transitions = transitions_jr_the_second.copy()

long_sentence_count = policy_transitions[policy_transitions.compartment_duration == 600].total_population.sum()

transitions_to_reallocate = long_sentence_count * long_finite_sentences * PAROLE_GRANT_RATE
print(f'percent of transitions to reallocate: {transitions_to_reallocate / policy_transitions.total_population.sum() * 100}')

policy_transitions = policy_transitions.append(pd.DataFrame({
    'compartment': ['prison'] * 6,
    'outflow_to': ['release'] * 6,
    'crime_type': ['NA'] * 6,
    'total_population': age_breakdown['51+ count'] / age_breakdown['51+ count'].sum() * transitions_to_reallocate,
    'compartment_duration': [29 * 12, 28 * 12, 27 * 12, 25.5 * 12, 22.5 * 12, 20 * 12]
}))

policy_transitions.loc[
    policy_transitions.compartment_duration == 600, 'total_population'
] *= 1 - long_finite_sentences * PAROLE_GRANT_RATE

assert policy_transitions.total_population.sum() == transitions_jr_the_second.total_population.sum()

def grant_parole_to_long_sentences():
    return partial(TransitionTable.use_alternate_transitions_data, 
                   alternate_historical_transitions=policy_transitions,
                   retroactive=True)

policy_list = []
policy_list.append(SparkPolicy(policy_fn=grant_parole_to_long_sentences(),
                                       spark_compartment='prison',
                                       sub_population={'crime_type': 'NA'},
                                       policy_ts=36, #jan 2023
                                       apply_retroactive=True))


test_results = spark_sim.simulate_policy(policy_list, 'prison')
# Out:
# percent of transitions to reallocate: 0.3402932120475237
# initialization time:  12.743780136108398
# initialization time:  6.720928907394409
# simulation_time:  5.808513164520264
# simulation_time:  5.269416809082031

# %%
simulation_tag = 'LA_HB_728_4/19/22'
outputs = spark_sim.upload_policy_simulation_results_to_bq(simulation_tag)
